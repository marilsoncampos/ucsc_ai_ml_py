# %% [markdown]
# ### Course Project: Titanic Exploratory Data Analysis and Model

# %% [markdown]
# #### 1. The problem
#
# ~~~~
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered
# “unsinkable” RMS Titanic sank after colliding with an iceberg.
#
# Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting
# in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some
# groups of people were more likely to survive than others.
#
#
# ~~~~

# %% [markdown]
# #### 2. The Project:
#
# Perform an __Exploratory data analysis (EDA)__ on the 'Titanic' dataset and build a model to predict passenger survival.
#
# ##### During the EDA process, your goal is to understand the data including:
#
# - Missing values
# - Relationships between two __predictor variables__.
# - Relationships between a __predictor variable__ and the __predicted (target) variable__.
#
# A common practice is to ask questions relevant to the problem and explain what you see.
#
# Your goal is to build a __document that reads like a story__, having a 'beginning', 'middle', and an 'end'.
#
# It should include findings even if the conclusion are something like this:
#
# ```
# Based on our analysis of the data, there is no indication that variable 'X' influences the Survival.
# ```
#
# #### 3. Grading:
#
# __Your grade will not depend on the peformance of your final model__.
#
# __Instead, I will focus on where you started and what steps you took to get to the report.__
#
# __Note:__ The reason for this choice is that, there are many factors that influence the final MaL performance. (Including the ML algorithm selected).
#
# #### 4. Report Structure:
#
# __Your report should include the following areas:__
#
#
# * Loading the data sets.
#
# * Try to understand the field types, value distribution, missing data, etc.
#
# * Summarize/visualize data slices and explain your findings.
#
# * Fix missing/incorrect data fields.
#
# * Use 'Feature engineering,' to create new features from the original data.
#
# * Formulate some hypotheses about the data.
#
# * Build and tune the model. (I am providing a sample code for this part so you can adjust it.)
#
#
# #### 5. Suggested report outline.
#
# ##
# **Section 1. Data Loading, cleaning and fixes**
#
# Load the data for trainning and testing.
#
# Inspect the values for each field and indentify problems with the data.
#
# Here are few ideas to explore:
#
# _A. Questions about ways to complete missing data._
#
# * Can I use the person's __title__ listed in the ticket to estimate age?
# * Can I use the passenger gender to estimate age?
#
# ##
# **Section 2. Hypothesis formulation**
#
# Here are a few example questions to explore:
#
# _A. Questions about features (Predictors)_
#
# * Is the size of the group a determinant factor in the survival ?
# * How is survival influenced based on passenger ticket class?
# * How does age influence survival?
#
# _B. Map two feature against survival_
# * How can we see the effect of 'Group size' and 'Age' on chances of survival?
#
# ##
# **Section 3. Feature Engineering**
#
# _A. Ideas about creating new features_
#
# * Can I use ticket information to generate information about the passenger's location on the ship?
# * Can we extract information about the title to assign passengers into groups like 'members of clergy,' 'widows,' 'soldiers,' etc.?
#
# ##
# **Section 4. Summarization of findings**
#
# For each of your hypothesis:
#
# - Create a visual plot to help confirm or reject the premise.
# - Add comments about what you see and your conclusions.
#
# ##
# **Section 5. Build an initial prediction model for surviving the accident.**
#
# Using the template code provided:
#
# - Create a model using at least six features
#
# ##
# **Section 6. Tune the prediction model.**
#
# Using the template code provided:
# - Add comments about your findings before optimization (if any).
# - Optimize the model by adjusting the hyperparameters values.
#
# ##
# **Section 7. Final Notes & Recommendations**
#
# Complete your report.
#
# Here are some ideas to explore:
#
# * A summary of your conclusions
# * A list of few steps to work on in the future.
# * List any limitation on the data that if removed could produce better results.
