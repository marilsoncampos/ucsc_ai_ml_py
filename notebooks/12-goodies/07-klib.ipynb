# %%
# !pip install -U klib
# Out:
# Collecting klib
#   Downloading klib-1.0.7-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from klib) (1.9.3)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from klib) (1.5.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.11.2 in /opt/conda/lib/python3.10/site-packages (from klib) (0.12.1)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in /opt/conda/lib/python3.10/site-packages (from klib) (1.23.5)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /opt/conda/lib/python3.10/site-packages (from klib) (3.1.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in /opt/conda/lib/python3.10/site-packages (from klib) (3.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0.0,>=1.2.0->klib) (2022.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)
# Installing collected packages: klib
# Successfully installed klib-1.0.7

# %%
import klib
import pandas as pd

# %% [markdown]
# ## Summary of functions.
#
# ### klib.describe - functions for visualizing datasets
# - klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# - klib.corr_mat(df) # returns a color-encoded correlation matrix
# - klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# - klib.dist_plot(df) # returns a distribution plot for every numeric feature
# - klib.missingval_plot(df) # returns a figure containing information about missing values
#
# ### klib.clean - functions for cleaning datasets
# - klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# - klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# - klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# - klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# - klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# - klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
klib.dist_plot(df['Fare'])
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='Density'>

# %%
klib.cat_plot(df[['Sex', 'Embarked']], top=3, bottom=3)
# Out:
# GridSpec(6, 2)
